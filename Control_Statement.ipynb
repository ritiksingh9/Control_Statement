# %%
Name=input("Enter the name:")
print("Hello",Name)
# Out:
# Enter the name: Ritik
# Hello Ritik

# %%
#Write a program to print hello ritik kumar singh

# %%
Name=input("Enter the name:")
print("Hello",Name)
# Out:
# Enter the name: Ritik kumar singh
# Hello Ritik kumar singh

# %%
age=int(input("Enter the age:"))
print("His age is",age)
# Out:
# Enter the age: 78
# His age is 78

# %%
data = eval(input("Enter value: "))
print(type(data))
# Out:
# Enter value:  [1,2,3]
# <class 'list'>

# %%
data=eval(input("enter the number:"))
print(type(data))
# Out:
# enter the number: [1,2,4]
# <class 'list'>

# %%
age=eval(input("enter the age:"))
if age>=18:
    print("He/she eligible for vote:")
# Out:
# enter the age: 18
# He/she eligible for vote:

# %%
age=18
if age>=18:
    print("Eligible for vote:")
else:
    print("Not eligible for vote")
# Out:
# Eligible for vote:

# %%
#Converting all lower case into the upper case:-

# %%
text='I LOVE YOU  ,I LOVE YOU,I LOVE AI ,WIN'
print(text.lower())
# Out:
# i love you  ,i love you,i love ai ,win

# %%
a=10
b=20
c=30
d=40
print(a,b,c,d,sep='#',end='_')
# Out:
# 10#20#30#40_

# %%
a=10
if a%2==0:
    print("even")
# Out:
# even

# %%
num=int(input("Enter the number:"))
if num%2==0:
    print("even")
# Out:
# Enter the number: 10
# even

# %%
num=10
if num%2==0:
    print("even")
    print(num**2)
# Out:
# even
# 100

# %%
char='a'
if char in ['a','e','i','o','u']:
    print('vowel')
# Out:
# vowel

# %%
char=input("Enter the character:")
if 'A' <=char<= 'Z':
    print(ord(char))
# Out:
# Enter the character: A
# 65

# %%
#WAP TP PRINT THE CUBE OF THE UMBER ONLY IF IT SI DIVISIBLE BY 9 OR 6?

# %%
num=int(input("Enter the number:"))
if num%6==0 or num%9==0:
    print(num**3)
# Out:
# Enter the number: 9
# 729

# %%
num=int(input("Enter the number:"))
if 100<=num<=999:
    print("The number is 3 digit number")
# Out:
# Enter the number: 555
# The number is 3 digit number

# %%
num=int(input("Enter the number:"))
if num%10==5:
    print("The number is ending with 5")
# Out:
# Enter the number: 105
# The number is ending with 5

# %%
data=eval(input("Enter the data:"))
if type(data) in [int,float,complex,bool]:
    print("The data is SVD")
# Out:
# Enter the data: 10
# The data is SVD

# %%
data=eval(input("Enter the data:"))
if type(data) in [int,float,complex,bool]:
    print("The data is SVD")
# Out:
# Enter the data: 4.5
# The data is SVD

# %%
char=input("Enter the digit:")
if '0'<= char<='9':
    print("The given character is digit")
# Out:
# Enter the digit: 4
# The given character is digit

# %%
num=int(input("Enter the number:"))
if num%3==0:
        print("The number is multiple of 3")
else:
    print("The number is not multiple of 3")
# Out:
# Enter the number: 5
# The number is not multiple of 3

# %%
value=input("Enter the string:")
if value==value[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# Enter the string: anna
# palindrome

# %%
#WAP TO CHECK WHETHER THE DATA IS MUTABLE OR NOT?

# %%
data=eval(input("Enter the data:"))
if type(data) in [list,set,dict]:
    print("It is mutable")
else:
    print("It is not mutable")
# Out:
# Enter the data: [1,3,4]
# It is mutable

# %%
#WAP TO CHECK WHETHER THE GIVEN CHARACTER IS DIGIT OR NOT?

# %%
char=input("Enter the data:")
if '0' <=char<='9':
    print("It is digit")
else:
    print("It is not a digit")
# Out:
# Enter the data: 1
# It is digit

# %%
char=input("Enter the data:")
if '0'<=char<='9' or  'A'<=char<='Z' or  'a'<=char<='z':
    print("This is special character") 
else:
    print("This is  not special character")
# Out:
# Enter the data: %
# This is  not special character
